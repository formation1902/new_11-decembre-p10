# %%
import pandas as pd

# %%
df = pd.read_csv('model_data/training_data.csv')

# %%
df.shape
# Out:
# (1394, 12)

# %%
df
# Out:
#       original_index  agentRate  wizardSuccess intent  absent_n  \
# 0                  0        4.0           True   book         1
# 1                  7        3.0           True   book         2
# 2                 48        5.0           True   book         1
# 3                 61        5.0           True   book         2
# 4                 70        3.0           True   book         3
# ...              ...        ...            ...    ...       ...
# 1389           19930        5.0           True   book         4
# 1390           19950        5.0           True   book         5
# 1391           19954        4.0           True   book         5
# 1392           19974        5.0           True   book         4
# 1393           19982        5.0           True   book         5
#
#                       composite  \
# 0     a_definir_apres_selection
# 1     a_definir_apres_selection
# 2     a_definir_apres_selection
# 3     a_definir_apres_selection
# ...

# %%
df.date_depart.value_counts()
# Out:
# August 27th       12
# August 27          8
# Sept 6             8
# September 8        7
# August 17          6
#                   ..
# september 4        1
# August 29th        1
# september 16th     1
# Aug 21             1
# sept 6             1
# Name: date_depart, Length: 187, dtype: int64

# %%
for var in df.columns[-5:]:
    df[df[var]==-1].shape

# %%
df[df.absent_n==5].shape
# Out:
# (476, 12)

# %%
df[df.absent_n==5].head(1).T
# Out:
#                                                    7
# original_index                                   155
# agentRate                                        5.0
# wizardSuccess                                   True
# intent                                          book
# absent_n                                           5
# composite                  a_definir_apres_selection
# text               Ok, I'm ready to buy this package
# ville_depart                                     NaN
# ville_destination                                NaN
# date_depart                                      NaN
# date_retour                                      NaN
# budget                                           NaN
